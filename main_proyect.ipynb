# %%
from funciones import *

import warnings
warnings.filterwarnings('ignore')

url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"

rename_map = {"unnamed: 11":"fatality"}
    
mappings = {
    "type": {
    "Invalid": "Under investigation",
    "Boat": "Watercraft",
    " Provoked": "Provoked",
    "?": "Under investigation",
    "Unconfirmed": "Under investigation",
    "Unverified": "Under investigation",
    "Questionable": "Under investigation"
    },
    "fatality": {
    "M": "No especificado",
    "F": "No especificado",
    "UNKNOWN": "No especificado",
    "n": "No especificado",
    "Nq": "No especificado",
    2017: "No especificado"
},
    "country": {
    "REUNION": "REUNION ISLAND"}
   
}

places = ["country","state","location"]

limits = {"year":2000,"country":30}

patron_negativo = r'\?|[0-9]|beetween'


keywords = r'bathing|boat|boating|surfing|boarding|diving|dived|dive|fell|fishing|floating|snorkeling|paddle|paddling|kayaking|jump|jumping|swimming|sailing'

fill_values = {
    "type": "No especificado",
    "country": "No especificado",
    "location": "No especificado",
    "fatality": "No especificado"
}


df_limpio = main(url, rename_map, mappings, places, patron_negativo, limits, keywords, fill_values)

df_limpio.head()
# Out:
#         date  year        type    country              state  \
# 0 2024-03-15  2024  Unprovoked  AUSTRALIA         Queensland
# 1 2024-03-04  2024  Unprovoked        USA             Hawaii
# 2 2024-03-02  2024  Unprovoked        USA             Hawaii
# 3 2024-02-25  2024  Unprovoked  AUSTRALIA  Western Australia
# 6 2024-01-29  2024  Unprovoked  AUSTRALIA   New  South Wales
#
#                        location  activity            name sex  age  \
# 0                 Bargara Beach  swimming  Brooklyn Sauer   F   13
# 1            Old Man's, Waikiki   surfing   Matthew White   M  NaN
# 2                Rainbows, Oahu  swimming             NaN   F   11
# 3    Sandlnd Island, Jurian Bay       NaN          female   F   46
# 6  Elizabeth Bay, Sydney Harbor  swimming  Lauren O'Neill   F   29
#
#                                      injury         fatality   time  \
# 0  Minor injuries to back, abdomen and legs  No especificado  16h00
# ...
